# %% [markdown]
# # Completer Test
#
# This notebook is made for assessing the performence of the QPL completer alone

# %% [markdown]
# ## Generate Completions

# %%
from transformers.models.auto.tokenization_auto import AutoTokenizer
from peft import AutoPeftModelForCausalLM
from processors import ProcessorRegistry
from datasets import load_dataset
from tqdm import tqdm

from utils.generation import to_model_prompt, generate_batch
import utils.paths as p

# Constants
BATCH_SIZE = 6
MAX_NEW_TOKENS = 128
MODEL_CKPT = "855d8cb9_gemma-3-4b-it-qpl-composer-ds_train_batch_size=1_gradient_accumulation_steps=8_learning_rate=0.0002_num_train_epochs=4_gradient_checkpointing=True_logging_steps=0.00125_save_steps=0.0625_random_seed=1_lora=True_r=16_alpha=32_dropout=0.05/checkpoint-3996"
MODEL_PATH = p.TRAINED_MODELS_DIR / MODEL_CKPT
DATASET_ID = "d4nieldev/qpl-completer-ds"


# Load model & tokenizer
model = AutoPeftModelForCausalLM.from_pretrained(MODEL_PATH, attn_implementation='eager').cuda()
model = model.eval()
tokenizer = AutoTokenizer.from_pretrained(MODEL_PATH)

# Load and process data
test_dataset = list(load_dataset(DATASET_ID, split="validation"))
processor = ProcessorRegistry.get(DATASET_ID)(with_assistant=False)
chat_templates = list(map(processor.to_chat_template, test_dataset))
prompts = list(map(lambda ct: to_model_prompt(tokenizer, ct), chat_templates))

# Decompose questions
outputs = generate_batch(
    model=model,
    tokenizer=tokenizer,
    model_prompts=prompts,
    batch_size=BATCH_SIZE,
    max_new_tokens=MAX_NEW_TOKENS,
    progress_bar=tqdm(total=len(prompts), desc="Completing QPL"),
    do_sample=False,
)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Completing QPL: 100%|██████████| 3012/3012 [34:38<00:00,  1.45it/s]

# %% [markdown]
# ## Evaluate

# %%
import re
from typing import List

processor = ProcessorRegistry.get(DATASET_ID)(with_assistant=True)
chat_templates = []
for example in test_dataset:
    chat_templates.append(processor.to_chat_template(example))


def equivalent_bracketed_lines(true_line: str,
                               generated_line: str,
                               *,
                               require_exact_names: bool = False,
                               ignore_case: bool = True) -> bool:
    _ZERO_DECIMAL = re.compile(r'(?<![\d.])(\d+)\.0+\b')
    _TABLE_COL    = re.compile(r'#\d+\.\s*[\w$]+', flags=re.I)
    _EQUALITY     = re.compile(rf'({_TABLE_COL.pattern})\s*=\s*({_TABLE_COL.pattern})',
                               flags=re.I)

    def _norm_nums(txt: str) -> str:
        return _ZERO_DECIMAL.sub(r'\1', txt)

    # ---- build equivalence classes from join predicates
    def _build_equiv_map(*lines: str) -> dict[str, str]:
        parent = {}

        def find(x):
            parent.setdefault(x, x)
            if parent[x] != x:
                parent[x] = find(parent[x])
            return parent[x]

        def union(a, b):
            ra, rb = find(a), find(b)
            if ra != rb:
                parent[rb] = ra

        for line in lines:
            for block in re.findall(r'Predicate\s*\[([^\]]*)\]',
                                    _norm_nums(line), flags=re.I):
                for left, right in _EQUALITY.findall(block):
                    l = left.replace(' ', '')
                    r = right.replace(' ', '')
                    if ignore_case:
                        l, r = l.upper(), r.upper()
                    union(l, r)

        equiv = {}
        for full in parent:
            col = full.split('.', 1)[1]
            root = find(full)
            equiv[full] = col.upper() if ignore_case else col
            if root not in equiv:
                equiv[root] = equiv[full]
        return equiv

    EQUIV = _build_equiv_map(true_line, generated_line)

    # ---- compare skeletons (outside brackets)
    def _skeleton(txt: str) -> str:
        txt = _norm_nums(txt)
        txt = re.sub(r'\[[^\]]*]', '[]', txt)
        txt = re.sub(r'\s+', ' ', txt).strip()
        return txt.upper() if ignore_case else txt

    if _skeleton(true_line) != _skeleton(generated_line):
        return False

    # ---- helper to extract bracket contents
    blocks = lambda s: re.findall(r'\[([^\]]*)]', _norm_nums(s))

    t_blocks, g_blocks = blocks(true_line), blocks(generated_line)
    if len(t_blocks) != len(g_blocks):
        return False

    # ---- canonicalise individual tokens
    def canon(tok: str) -> str:
        tok = re.split(r'\s+AS\s+', tok, flags=re.I)[0]
        tok = re.sub(r'\s+', ' ', tok).strip()
        tok = _norm_nums(tok)

        def repl(m):
            key = m.group(0).replace(' ', '')
            key = key.upper() if ignore_case else key
            return EQUIV.get(key, m.group(0))

        tok = _TABLE_COL.sub(repl, tok)
        return tok.upper() if ignore_case else tok

    # ---- compare each corresponding block
    for tb, gb in zip(t_blocks, g_blocks):
        t_set = {canon(tok) for tok in tb.split(',') if tok.strip()}
        g_set = {canon(tok) for tok in gb.split(',') if tok.strip()}

        if require_exact_names:
            if t_set != g_set:
                return False
        else:
            if not t_set.issubset(g_set):
                return False

    return True


acc = 0
for out, chat_template, example in tqdm(zip(outputs, chat_templates, test_dataset), desc="Evaluating", total=len(outputs)):
    label = chat_template['messages'][-1]['content']
    equivalent = equivalent_bracketed_lines(
        label,
        out,
    )
    if not equivalent:
        print("Question:")
        print(example['question'])
        print('-'*40)
        print("Predicted:")
        print(example['op'], out)
        print('-'*40)
        print("True:")
        print(example['op'], label)
        print("=" * 80)
    else:
        acc += 1

print(f"Accuracy: {acc}/{len(outputs)} = {acc / len(outputs) * 100:.2f}%")
# Out:
# WARNING:root:Parent not found for question: Find the student ids in all records of student id and pet id.
# WARNING:root:Parent not found for question: Find the id of cat pets.
# WARNING:root:Parent not found for question: Find the id of students and their pet ids.
# WARNING:root:Parent not found for question: List the id and name of all continents.
# WARNING:root:Parent not found for question: What are the ids and models of all cars?
# WARNING:root:Parent not found for question: List the countries ids of all car makers.
# WARNING:root:Parent not found for question: List the number of car makers for each country id.
# WARNING:root:Parent not found for question: What is the weight and year of all cars?
# WARNING:root:Parent not found for question: List 1 for each car with over 6 cylinders.
# WARNING:root:Parent not found for question: Find the source airport code of all flights.
# WARNING:root:Parent not found for question: Find the airline id of all flights.
# WARNING:root:Parent not found for question: Find the source city of all flights.
# WARNING:root:Parent not found for question: Find the number of departing flights for each city.
# WARNING:root:Parent not found for question: What are the ids and countries of all tv channels?
# WARNING:root:Parent not found for question: Find the id and country of all tv channels.
# WARNING:root:Parent not found for question: Find the different countries and the number of tv channels from each.
# WARNING:root:Parent not found for question: Find the countries where have more than two tv channels.
# WARNING:root:Parent not found for question: find id of the tv channels that from the countries where have more than two tv channels.
# WARNING:root:Parent not found for question: What is the number of TV channels in each country?
# WARNING:root:Parent not found for question: What are the countries that have more than 2 TV channels?
# WARNING:root:Parent not found for question: What are the ids of all tv channels in countries that have more than 2 TV channels?
# WARNING:root:Parent not found for question: What are the names and continents of countries that have a population of 80000?
# WARNING:root:Parent not found for question: What are the names of the countries that are in the continent of Europe and have a population of 80000?
# WARNING:root:Parent not found for question: Give the names and continents of countries that have a population equal to 80000.
# WARNING:root:Parent not found for question: Give the names of countries that are in Europe and have a population equal to 80000.
# WARNING:root:Parent not found for question: List the id, first name and last name of all owners.
# Evaluating:  30%|███       | 915/3012 [00:00<00:00, 4440.26it/s]
# Question:
# What is the maximum capacity and the average of all stadiums ?
# ----------------------------------------
# Predicted:
# Aggregate[ #1 ] Output [ AVG(Capacity) AS Avg_Capacity , MAX(Capacity) AS Max_Capacity ]
# ```
# ----------------------------------------
# True:
# Aggregate[ #1 ] GroupBy [ Average ] Output [ Average , MAX(Capacity) AS Max_Capacity ]
# ```
# ================================================================================
# Question:
# List the stadium name of all concerts.
# ----------------------------------------
# Predicted:
# Join[ #1 , #2 ] Predicate [ #1.Stadium_ID = #2.Stadium_ID ] Output [ #2.Name ]
# ```
# ----------------------------------------
# True:
# Join[ #1 , #2 ] Predicate [ #1.Stadium_ID = #2.Stadium_ID ] Output [ #1.Stadium_ID , #2.Name ]
# ```
# ================================================================================
# Question:
# Show the stadium names without any concert.
# ----------------------------------------
# Predicted:
# Except[ #1 , #2 ] Predicate [ #2.Stadium_ID = #1.Stadium_ID ] Output [ #1.Name ]
# ```
# ----------------------------------------
# True:
# Except[ #1 , #2 ] Predicate [ #2.Stadium_ID IS NULL OR #1.Stadium_ID = #2.Stadium_ID ] Output [ #1.Name ]
# ```
# ================================================================================
# Question:
# What are the names of the stadiums without any concerts?
# ----------------------------------------
# Predicted:
# Except[ #1 , #2 ] Predicate [ #2.Stadium_ID = #1.Stadium_ID ] Output [ #1.Name ]
# ```
# ----------------------------------------
# True:
# Except[ #1 , #2 ] Predicate [ #2.Stadium_ID IS NULL OR #1.Stadium_ID = #2.Stadium_ID ] Output [ #1.Name ]
# ```
# ================================================================================
# Question:
# Show countries where a singer below age 30 are from.
# ----------------------------------------
# Predicted:
# ScanTable [ singer ] Predicate [ Age < 30 ] Distinct [ true ] Output [ Country , Age ]
# ```
# ----------------------------------------
# True:
# ScanTable [ singer ] Predicate [ Age < 30 ] Output [ Country , Age ]
# ```
# ================================================================================
# Question:
# What are the ids of concerts in 2014?
# ----------------------------------------
# Predicted:
# ScanTable [ concert ] Predicate [ Year = 2014 ] Output [ concert_ID , Year ]
# ```
# ----------------------------------------
# True:
# ScanTable [ concert ] Predicate [ Year = 2014 ] Output [ Year , Stadium_ID ]
# ```
# ================================================================================
# Question:
# what is the name and nation of the singer who have a song having 'Hey' in its name?
# ----------------------------------------
# Predicted:
# ScanTable [ singer ] Predicate [ Song_Name like '%Hey%' ] Output [ Country , Song_Name , Is_male ]
# ```
# ----------------------------------------
# True:
# ScanTable [ singer ] Predicate [ Song_Name like '%Hey%' ] Output [ Name , Song_Name , Country ]
# ```
# ================================================================================
# Question:
# What is the name and country of origin of every singer who has a song with the word 'Hey' in its title?
# ----------------------------------------
# Predicted:
# ScanTable [ singer ] Predicate [ Song_Name like '%Hey%' ] Output [ Country , Song_Name ]
# ```
# ----------------------------------------
# True:
# ScanTable [ singer ] Predicate [ Song_Name like '%Hey%' ] Output [ Name , Song_Name , Country ]
# ```
# ================================================================================
# Question:
# Find the name and location of the stadiums which some concerts happened in the years of 2014.
# ----------------------------------------
# Predicted:
# Join[ #1 , #2 ] Predicate [ #1.Stadium_ID = #2.Stadium_ID ] Output [ #2.Name , #2.Location ]
# ```
# ----------------------------------------
# True:
# Join[ #1 , #2 ] Predicate [ #1.Stadium_ID = #2.Stadium_ID ] Distinct [ true ] Output [ #2.Location , #2.Name ]
# ```
# ================================================================================
# Question:
# What are the names and locations of the stadiums that had concerts that occurred in 2014?
# ----------------------------------------
# Predicted:
# Join[ #1 , #2 ] Predicate [ #1.Stadium_ID = #2.Stadium_ID ] Output [ #2.Name , #2.Location ]
# ```
# ----------------------------------------
# True:
# Join[ #1 , #2 ] Predicate [ #1.Stadium_ID = #2.Stadium_ID ] Distinct [ true ] Output [ #2.Location , #2.Name ]
# ```
# ================================================================================
# Question:
# Find the dog pets ids that are raised by female students.
# ----------------------------------------
# Predicted:
# Join[ #3 , #4 ] Predicate [ #3.StuID = #4.StuID ] Output [ #3.PetID ]
# ```
# ----------------------------------------
# True:
# Join[ #3 , #4 ] Predicate [ #3.StuID = #4.StuID ] Output [ #3.StuID ]
# ```
# ================================================================================
# Question:
# Find the first name of students who have cat or dog pet.
# ----------------------------------------
# Predicted:
# Join[ #3 , #4 ] Predicate [ #3.StuID = #4.StuID ] Output [ #4.Fname ]
# ```
# ----------------------------------------
# True:
# Join[ #3 , #4 ] Predicate [ #3.StuID = #4.StuID ] Distinct [ true ] Output [ #4.Fname ]
# ```
# ================================================================================
# Question:
# What are the first names of every student who has a cat or dog as a pet?
# ----------------------------------------
# Predicted:
# Join[ #3 , #4 ] Predicate [ #3.StuID = #4.StuID ] Output [ #4.Fname ]
# ```
# ----------------------------------------
# True:
# Join[ #3 , #4 ] Predicate [ #3.StuID = #4.StuID ] Distinct [ true ] Output [ #4.Fname ]
# ```
# ================================================================================
# Question:
# What are the students' first names who have dogs?
# ----------------------------------------
# Predicted:
# Join[ #8 , #9 ] Predicate [ #8.StuID = #9.StuID ] Distinct [ true ] Output [ #9.Fname ]
# ```
# ----------------------------------------
# True:
# Join[ #8 , #9 ] Predicate [ #8.StuID = #9.StuID ] Output [ #9.Fname ]
# ```
# ================================================================================
# Question:
# Find the first name and age of students who have a pet.
# ----------------------------------------
# Predicted:
# Join[ #1 , #2 ] Predicate [ #1.StuID = #2.StuID ] Output [ #2.Age , #2.Fname ]
# ```
# ----------------------------------------
# True:
# Join[ #1 , #2 ] Predicate [ #1.StuID = #2.StuID ] Distinct [ true ] Output [ #2.Age , #2.Fname ]
# ```
# ================================================================================
# Question:
# Find the id of cats that is age 3.
# ----------------------------------------
# Predicted:
# ScanTable [ Pets ] Predicate [ pet_age = 3 ] Output [ PetID , pet_age ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Pets ] Predicate [ pet_age = 3 AND PetType = 'cat' ] Output [ PetType , PetID , pet_age ]
# ```
# ================================================================================
# Question:
# Find the age of students who do not have any pet.
# ----------------------------------------
# Predicted:
# Except[ #1 , #2 ] Predicate [ #2.StuID = #1.StuID ] Output [ #1.Age ]
# ```
# ----------------------------------------
# True:
# Except[ #1 , #2 ] Predicate [ #2.StuID IS NULL OR #1.StuID = #2.StuID ] Output [ #1.Age ]
# ```
# ================================================================================
# Question:
# What is the age for all students who do not own any pets?
# ----------------------------------------
# Predicted:
# Except[ #1 , #2 ] Predicate [ #2.StuID = #1.StuID ] Output [ #1.Age ]
# ```
# ----------------------------------------
# True:
# Except[ #1 , #2 ] Predicate [ #2.StuID IS NULL OR #1.StuID = #2.StuID ] Output [ #1.Age ]
# ```
# ================================================================================
# Question:
# Find the id and model of all cars.
# ----------------------------------------
# Predicted:
# ScanTable [ model_list ] Output [ ModelId , Model ]
# ```
# ----------------------------------------
# True:
# ScanTable [ car_names ] Output [ MakeId , Model ]
# ```
# ================================================================================
# Question:
# What is the id and model of all cars?
# ----------------------------------------
# Predicted:
# ScanTable [ model_list ] Output [ ModelId , Model ]
# ```
# ----------------------------------------
# True:
# ScanTable [ car_names ] Output [ MakeId , Model ]
# ```
# ================================================================================
# Question:
# Find the id and model of all cars.
# ----------------------------------------
# Predicted:
# ScanTable [ model_list ] Output [ ModelId , Model ]
# ```
# ----------------------------------------
# True:
# ScanTable [ car_names ] Output [ MakeId , Model ]
# ```
# ================================================================================
# Question:
# What is the id and model of all cars?
# ----------------------------------------
# Predicted:
# ScanTable [ model_list ] Output [ ModelId , Model ]
# ```
# ----------------------------------------
# True:
# ScanTable [ car_names ] Output [ MakeId , Model ]
# ```
# ================================================================================
# Question:
# Find the id and model of all cars.
# ----------------------------------------
# Predicted:
# ScanTable [ model_list ] Output [ ModelId , Model ]
# ```
# ----------------------------------------
# True:
# ScanTable [ car_names ] Output [ MakeId , Model ]
# ```
# ================================================================================
# Question:
# Find the name of the makers that produced some cars in the year of 1970?
# ----------------------------------------
# Predicted:
# Join[ #1 , #6 ] Predicate [ #1.Id = #6.Maker ] Output [ #1.Maker ]
# ```
# ----------------------------------------
# True:
# Join[ #1 , #6 ] Predicate [ #1.Id = #6.Maker ] Distinct [ true ] Output [ #1.Maker ]
# ```
# ================================================================================
# Question:
# What is the id and model of all cars?
# ----------------------------------------
# Predicted:
# ScanTable [ model_list ] Output [ ModelId , Model ]
# ```
# ----------------------------------------
# True:
# ScanTable [ car_names ] Output [ MakeId , Model ]
# ```
# ================================================================================
# Question:
# What is the name of the different car makers who produced a car in 1970?
# ----------------------------------------
# Predicted:
# Join[ #1 , #6 ] Predicate [ #1.Id = #6.Maker ] Output [ #1.Maker ]
# ```
# ----------------------------------------
# True:
# Join[ #1 , #6 ] Predicate [ #1.Id = #6.Maker ] Distinct [ true ] Output [ #1.Maker ]
# ```
# ================================================================================
# Question:
# What are the ids and models of all cars?
# ----------------------------------------
# Predicted:
# ScanTable [ model_list ] Output [ ModelId , Model ]
# ```
# ----------------------------------------
# True:
# ScanTable [ car_names ] Output [ Model , MakeId ]
# ```
# ================================================================================
# Question:
# What are the names of countries of manufacturers in Europe?
# ----------------------------------------
# Predicted:
# Join[ #3 , #4 ] Predicate [ #4.Country = #3.CountryId ] Output [ #3.CountryName ]
# ```
# ----------------------------------------
# True:
# Join[ #3 , #4 ] Predicate [ #3.CountryId = #4.Country ] Output [ #3.CountryName ]
# ```
# ================================================================================
# Question:
# List the id and model of all cars.
# ----------------------------------------
# Predicted:
# ScanTable [ model_list ] Output [ ModelId , Model ]
# ```
# ----------------------------------------
# True:
# ScanTable [ car_names ] Output [ MakeId , Model ]
# ```
# ================================================================================
# Question:
# What is the id and model of all cars?
# ----------------------------------------
# Predicted:
# ScanTable [ model_list ] Output [ ModelId , Model ]
# ```
# ----------------------------------------
# True:
# ScanTable [ car_names ] Output [ MakeId , Model ]
# ```
# ================================================================================
# Question:
# What is the id of the cars for all volvos?
# ----------------------------------------
# Predicted:
# ScanTable [ cars_data ] Predicate [ Model = 'Volvo' ] Output [ Id , Model ]
# ```
# ----------------------------------------
# True:
# ScanTable [ car_names ] Predicate [ Model = 'volvo' ] Output [ MakeId , Model ]
# ```
# ================================================================================
# Question:
# Show the model of all cars.
# ----------------------------------------
# Predicted:
# ScanTable [ cars_data ] Output [ Model ]
# ```
# ----------------------------------------
# True:
# ScanTable [ car_names ] Output [ Model ]
# ```
# ================================================================================
# Question:
# What is the id of the car maker American Motor Company?
# ----------------------------------------
# Predicted:
# ScanTable [ car_makers ] Predicate [ Maker = 'American Motors' ] Output [ Id , Maker ]
# ```
# ----------------------------------------
# True:
# ScanTable [ car_makers ] Predicate [ FullName = 'American Motor Company' ] Output [ FullName , Id ]
# ```
# ================================================================================
# Question:
# What are the names and ids of all makers.
# ----------------------------------------
# Predicted:
# ScanTable [ car_makers ] Output [ Id , Maker ]
# ```
# ----------------------------------------
# True:
# ScanTable [ car_makers ] Output [ FullName , Id ]
# ```
# ================================================================================
# Question:
# Find the ids and models of all cars.
# ----------------------------------------
# Predicted:
# ScanTable [ model_list ] Output [ ModelId , Model ]
# ```
# ----------------------------------------
# True:
# ScanTable [ car_names ] Output [ MakeId , Model ]
# ```
# ================================================================================
# Question:
# Find the models and weights of all cars.
# ----------------------------------------
# Predicted:
# Join[ #3 , #4 ] Predicate [ #3.MakeId = #4.Id ] Output [ #4.Weight , #3.Model ]
# ```
# ----------------------------------------
# True:
# Join[ #3 , #4 ] Predicate [ #4.Id = #3.MakeId ] Output [ #3.Model , #4.Weight ]
# ```
# ================================================================================
# Question:
# Find the models and weights and maker full names of all cars.
# ----------------------------------------
# Predicted:
# Join[ #1 , #6 ] Predicate [ #6.Maker = #1.Id ] Output [ #6.Weight , #6.Maker , #6.Model ]
# ```
# ----------------------------------------
# True:
# Join[ #1 , #6 ] Predicate [ #6.Maker = #1.Id ] Output [ #6.Model , #6.Weight , #1.FullName ]
# ```
# ================================================================================
# Question:
# What are the ids and models of all cars?
# ----------------------------------------
# Predicted:
# ScanTable [ model_list ] Output [ ModelId , Model ]
# ```
# ----------------------------------------
# True:
# ScanTable [ car_names ] Output [ Model , MakeId ]
# ```
# ================================================================================
# Question:
# What are the models and weights of all cars?
# ----------------------------------------
# Predicted:
# Join[ #3 , #4 ] Predicate [ #3.MakeId = #4.Id ] Output [ #4.Weight , #3.Model ]
# ```
# ----------------------------------------
# True:
# Join[ #3 , #4 ] Predicate [ #4.Id = #3.MakeId ] Output [ #3.Model , #4.Weight ]
# ```
# ================================================================================
# Question:
# What are the models and weights and car maker ids of all cars?
# ----------------------------------------
# Predicted:
# Join[ #2 , #5 ] Predicate [ #2.Maker = #5.Model ] Output [ #5.Weight , #2.Model ]
# ```
# ----------------------------------------
# True:
# Join[ #2 , #5 ] Predicate [ #5.Model = #2.Model ] Output [ #2.Model , #2.Maker , #5.Weight ]
# ```
# ================================================================================
# Question:
# What are the different models created by either the car maker General Motors or weighed more than 3500?
# ----------------------------------------
# Predicted:
# Filter[ #7 ] Predicate [ Weight > 3500.0 OR FullName = 'General Motors' ] Output [ Model , Weight , FullName ]
# ```
# ----------------------------------------
# True:
# Filter[ #7 ] Predicate [ Weight > 3500 Or FullName = 'General Motors' ] Distinct [ true ] Output [ Model ]
# ```
# ================================================================================
# Question:
# In which years cars were produced weighing no less than 3000 and no more than 4000 ?
# ----------------------------------------
# Predicted:
# ScanTable [ cars_data ] Predicate [ Weight >= 3000.0 AND Weight <= 4000.0 ] Output [ Weight , Year ]
# ```
# ----------------------------------------
# True:
# ScanTable [ cars_data ] Predicate [ Weight >= 3000 AND Weight <= 4000 ] Distinct [ true ] Output [ Year ]
# ```
# ================================================================================
# Question:
# What are the different years in which there were cars produced that weighed less than 4000 and also cars that weighted more than 3000 ?
# ----------------------------------------
# Predicted:
# ScanTable [ cars_data ] Predicate [ Weight < 4000.0 AND Weight > 3000.0 ] Distinct [ true ] Output [ Year ]
# ```
# ----------------------------------------
# True:
# ScanTable [ cars_data ] Predicate [ Weight >= 3000 AND Weight <= 4000 ] Distinct [ true ] Output [ Year ]
# ```
# ================================================================================
# Question:
# List the id and model of all cars.
# ----------------------------------------
# Predicted:
# ScanTable [ model_list ] Output [ ModelId , Model ]
# ```
# ----------------------------------------
# True:
# ScanTable [ car_names ] Output [ MakeId , Model ]
# ```
# ================================================================================
# Question:
# List the id and model of all cars.
# ----------------------------------------
# Predicted:
# ScanTable [ model_list ] Output [ ModelId , Model ]
# ```
# ----------------------------------------
# True:
# ScanTable [ car_names ] Output [ MakeId , Model ]
# ```
# ================================================================================
# Question:
# Find the id of makers that are not 'Ford Motor Company'.
# ----------------------------------------
# Predicted:
# ScanTable [ car_makers ] Predicate [ Maker <> 'Ford Motor Company' ] Output [ Id , Maker ]
# ```
# ----------------------------------------
# True:
# ScanTable [ car_makers ] Predicate [ FullName <> 'Ford Motor Company' ] Output [ FullName , Id ]
# ```
# ================================================================================
# Question:
# Find the ids and models of all cars.
# ----------------------------------------
# Predicted:
# ScanTable [ model_list ] Output [ ModelId , Model ]
# ```
# ----------------------------------------
# True:
# ScanTable [ car_names ] Output [ MakeId , Model ]
# ```
# ================================================================================
# Question:
# Which models are lighter than 3500 but not built by the 'Ford Motor Company'?
# ----------------------------------------
# Predicted:
# Join[ #1 , #6 ] Predicate [ #1.Id = #6.MakeId ] Output [ #1.Model ]
# ```
# ----------------------------------------
# True:
# Join[ #1 , #6 ] Predicate [ #1.Id = #6.MakeId ] Distinct [ true ] Output [ #6.Model ]
# ```
# ================================================================================
# Question:
# What are the ids and models of all cars?
# ----------------------------------------
# Predicted:
# ScanTable [ model_list ] Output [ ModelId , Model ]
# ```
# ----------------------------------------
# True:
# ScanTable [ car_names ] Output [ Model , MakeId ]
# ```
# ================================================================================
# Question:
# What is the id of the car maker that produces fiat model?
# ----------------------------------------
# Predicted:
# ScanTable [ car_names ] Predicate [ Model = 'Fiat' ] Output [ Model , Maker ]
# ```
# ----------------------------------------
# True:
# ScanTable [ model_list ] Predicate [ Model = 'fiat' ] Output [ Model , Maker ]
# ```
# ================================================================================
# Question:
# Find the source airport code of all flights.
# ----------------------------------------
# Predicted:
# ScanTable [ flights ] Output [ SourceAirport ]
# ```
# ----------------------------------------
# True:
# ScanTable [ airports ] Output [ AirportCode , City ]
# ```
# ================================================================================
# Question:
# List the airline id of flights arriving in ASY Airport.
# ----------------------------------------
# Predicted:
# ScanTable [ flights ] Predicate [ SourceAirport = 'ASY' ] Output [ SourceAirport , Airline ]
# ```
# ----------------------------------------
# True:
# ScanTable [ flights ] Predicate [ DestAirport = 'ASY' ] Output [ Airline , DestAirport ]
# ```
# ================================================================================
# Question:
# Find the destination airport code of all flights.
# ----------------------------------------
# Predicted:
# ScanTable [ flights ] Output [ DestAirport ]
# ```
# ----------------------------------------
# True:
# ScanTable [ airports ] Output [ AirportCode , City ]
# ```
# ================================================================================
# Question:
# Find the destination city of all flights.
# ----------------------------------------
# Predicted:
# Join[ #2 , #3 ] Predicate [ #2.DestAirport = #3.AirportCode ] Output [ #3.City ]
# ```
# ----------------------------------------
# True:
# Join[ #2 , #3 ] Predicate [ #2.DestAirport = #3.AirportCode ] Output [ #3.City , #2.Count_Star ]
# ```
# ================================================================================
# Question:
# Find the number of arriving flights for each city.
# ----------------------------------------
# Predicted:
# Aggregate[ #4 ] GroupBy [ City ] Output [ Count_Star AS Count_Star , City ]
# ```
# ----------------------------------------
# True:
# Aggregate[ #4 ] GroupBy [ City ] Output [ countstar AS Count_Star , City ]
# ```
# ================================================================================
# Question:
# Find the destination airport code of all flights.
# ----------------------------------------
# Predicted:
# ScanTable [ flights ] Output [ DestAirport ]
# ```
# ----------------------------------------
# True:
# ScanTable [ airports ] Output [ AirportCode , City ]
# ```
# ================================================================================
# Question:
# Find the destination city of all flights.
# ----------------------------------------
# Predicted:
# Join[ #2 , #3 ] Predicate [ #2.DestAirport = #3.AirportCode ] Output [ #3.City ]
# ```
# ----------------------------------------
# True:
# Join[ #2 , #3 ] Predicate [ #2.DestAirport = #3.AirportCode ] Output [ #3.City , #2.Count_Star ]
# ```
# ================================================================================
# Question:
# Find the number of arriving flights for each city.
# ----------------------------------------
# Predicted:
# Aggregate[ #4 ] GroupBy [ City ] Output [ Count_Star , City ]
# ```
# ----------------------------------------
# True:
# Aggregate[ #4 ] GroupBy [ City ] Output [ countstar AS Count_Star , City ]
# ```
# ================================================================================
# Question:
# Find the source airport code of all flights.
# ----------------------------------------
# Predicted:
# ScanTable [ flights ] Output [ SourceAirport ]
# ```
# ----------------------------------------
# True:
# ScanTable [ airports ] Output [ AirportCode , City ]
# ```
# ================================================================================
# Question:
# Find the source city of all flights.
# ----------------------------------------
# Predicted:
# Join[ #2 , #3 ] Predicate [ #2.SourceAirport = #3.AirportCode ] Output [ #3.City ]
# ```
# ----------------------------------------
# True:
# Join[ #2 , #3 ] Predicate [ #2.SourceAirport = #3.AirportCode ] Output [ #3.City , #2.Count_Star ]
# ```
# ================================================================================
# Question:
# Find the number of departing flights for each city.
# ----------------------------------------
# Predicted:
# Aggregate[ #4 ] GroupBy [ City ] Output [ Count_Star , City ]
# ```
# ----------------------------------------
# True:
# Aggregate[ #4 ] GroupBy [ City ] Output [ countstar AS Count_Star , City ]
# ```
# ================================================================================
# Question:
# Find the source airport code of all flights.
# ----------------------------------------
# Predicted:
# ScanTable [ flights ] Output [ SourceAirport ]
# ```
# ----------------------------------------
# True:
# ScanTable [ airports ] Output [ AirportCode , City ]
# ```
# ================================================================================
# Question:
# Find the source city of all flights.
# ----------------------------------------
# Predicted:
# Join[ #2 , #3 ] Predicate [ #2.SourceAirport = #3.AirportCode ] Output [ #3.City ]
# ```
# ----------------------------------------
# True:
# Join[ #2 , #3 ] Predicate [ #2.SourceAirport = #3.AirportCode ] Output [ #3.City , #2.Count_Star ]
# ```
# ================================================================================
# Question:
# Find the number of departing flights for each city.
# ----------------------------------------
# Predicted:
# Aggregate[ #4 ] GroupBy [ City ] Output [ Count_Star , City ]
# ```
# ----------------------------------------
# True:
# Aggregate[ #4 ] GroupBy [ City ] Output [ countstar AS Count_Star , City ]
# ```
# ================================================================================
# Question:
# What is the code of the airports that have a flight leaving from them or arriving at them?
# ----------------------------------------
# Predicted:
# Join[ #1 , #2 ] Predicate [ #2.DestAirport = #1.AirportCode OR #2.SourceAirport = #1.AirportCode ] Output [ #1.AirportCode ]
# ```
# ----------------------------------------
# True:
# Join[ #1 , #2 ] Predicate [ #1.AirportCode = #2.DestAirport OR #1.AirportCode = #2.SourceAirport ] Output [ #1.AirportCode ]
# ```
# ================================================================================
# Question:
# What are the airports codes that have a flight leaving from them or arriving at them?
# ----------------------------------------
# Predicted:
# Join[ #1 , #2 ] Predicate [ #2.DestAirport = #1.AirportCode OR #2.SourceAirport = #1.AirportCode ] Output [ #1.AirportCode ]
# ```
# ----------------------------------------
# True:
# Join[ #1 , #2 ] Predicate [ #1.AirportCode = #2.DestAirport OR #1.AirportCode = #2.SourceAirport ] Output [ #1.AirportCode ]
# ```
# ================================================================================
# Question:
# What is the code of the airports that have a flight leaving from them or arriving at them?
# ----------------------------------------
# Predicted:
# Join[ #1 , #2 ] Predicate [ #2.DestAirport = #1.AirportCode OR #2.SourceAirport = #1.AirportCode ] Output [ #1.AirportCode ]
# ```
# ----------------------------------------
# True:
# Join[ #1 , #2 ] Predicate [ #1.AirportCode = #2.DestAirport OR #1.AirportCode = #2.SourceAirport ] Output [ #1.AirportCode ]
# ```
# ================================================================================
# Question:
# Give the code of the airports that have a flight leaving from them or arriving at them.
# ----------------------------------------
# Predicted:
# Join[ #1 , #2 ] Predicate [ #2.DestAirport = #1.AirportCode OR #2.SourceAirport = #1.AirportCode ] Output [ #1.AirportCode ]
# ```
# ----------------------------------------
# True:
# Join[ #1 , #2 ] Predicate [ #1.AirportCode = #2.DestAirport OR #1.AirportCode = #2.SourceAirport ] Output [ #1.AirportCode ]
# ```
# ================================================================================
# Question:
# Which airlines have departing flights from APG airport?
# ----------------------------------------
# Predicted:
# Join[ #1 , #2 ] Predicate [ #1.Airline = #2.uid ] Output [ #2.Airline ]
# ```
# ----------------------------------------
# True:
# Join[ #1 , #2 ] Predicate [ #1.Airline = #2.uid ] Distinct [ true ] Output [ #2.Airline ]
# ```
# ================================================================================
# Question:
# Find all airlines that have at least 10 flights.
# ----------------------------------------
# Predicted:
# Filter[ #4 ] Predicate [ Count_Star >= 10 ] Output [ Airline ]
# ```
# ----------------------------------------
# True:
# Filter[ #4 ] Predicate [ Count_Star > 10 ] Output [ Airline ]
# ```
# ================================================================================
# Question:
# List the airlines of all flights.
# ----------------------------------------
# Predicted:
# Join[ #1 , #2 ] Predicate [ #1.uid = #2.Airline ] Output [ #1.Airline ]
# ```
# ----------------------------------------
# True:
# Join[ #1 , #2 ] Predicate [ #2.Airline = #1.uid ] Output [ #1.Airline ]
# ```
# ================================================================================
# Question:
# Which airlines have at least 10 flights?
# ----------------------------------------
# Predicted:
# Filter[ #4 ] Predicate [ Count_Star >= 10 ] Output [ Airline ]
# ```
# ----------------------------------------
# True:
# Filter[ #4 ] Predicate [ Count_Star > 10 ] Output [ Airline ]
# ```
# ================================================================================
# Question:
# Find the code of airports which have any flight in.
# ----------------------------------------
# Predicted:
# ScanTable [ flights ] Output [ SourceAirport ]
# ```
# ----------------------------------------
# True:
# ScanTable [ flights ] Output [ DestAirport AS AirportCode ]
# ```
# ================================================================================
# Question:
# Find the name of airports which do not have any flight in and out.
# ----------------------------------------
# Predicted:
# Except[ #1 , #4 ] Predicate [ #4.AirportCode = #1.AirportCode ] Output [ #1.AirportName ]
# ```
# ----------------------------------------
# True:
# Except[ #1 , #4 ] ExceptColumns [ #1.AirportCode ] Output [ #1.AirportName ]
# ```
# ================================================================================
# Question:
# Which airports do not have departing or arriving flights?
# ----------------------------------------
# Predicted:
# Except[ #1 , #4 ] Predicate [ #4.AirportCode = #1.AirportCode ] Output [ #1.AirportName ]
# ```
# ----------------------------------------
# True:
# Except[ #1 , #4 ] ExceptColumns [ #1.AirportCode ] Output [ #1.AirportName ]
# ```
# ================================================================================
# Question:
# Find the name of the shops that do not hire any employee.
# ----------------------------------------
# Predicted:
# Except[ #1 , #2 ] Predicate [ #2.Shop_ID = #1.Shop_ID ] Output [ #1.Name ]
# ```
# ----------------------------------------
# True:
# Except[ #1 , #2 ] Predicate [ #2.Shop_ID IS NULL OR #1.Shop_ID = #2.Shop_ID ] Output [ #1.Name ]
# ```
# ================================================================================
# Question:
# Which shops run with no employees? Find the shop names
# ----------------------------------------
# Predicted:
# Except[ #1 , #2 ] Predicate [ #2.Shop_ID = #1.Shop_ID ] Output [ #1.Name ]
# ```
# ----------------------------------------
# True:
# Except[ #1 , #2 ] Predicate [ #2.Shop_ID IS NULL OR #1.Shop_ID = #2.Shop_ID ] Output [ #1.Name ]
# ```
# ================================================================================
# Question:
# Which district has stores with more than 10000 products?
# ----------------------------------------
# Predicted:
# ScanTable [ shop ] Predicate [ Number_products > 10000.0 ] Distinct [ true ] Output [ District , Number_products ]
# ```
# ----------------------------------------
# True:
# ScanTable [ shop ] Predicate [ Number_products > 10000 ] Output [ Number_products , District ]
# ```
# ================================================================================
# Question:
# Find the districts in which there are shops selling more than 10000 products.
# ----------------------------------------
# Predicted:
# ScanTable [ shop ] Predicate [ Number_products > 10000.0 ] Distinct [ true ] Output [ District , Number_products ]
# ```
# ----------------------------------------
# True:
# ScanTable [ shop ] Predicate [ Number_products > 10000 ] Output [ Number_products , District ]
# ```
# ================================================================================
# Question:
# What is the document id, template id and description for document named "Robbin CV"?
# ----------------------------------------
# Predicted:
# ScanTable [ Documents ] Predicate [ Document_Name = 'Robbin CV' ] Output [ Document_Description , Template_ID , Document_Name , Other_Details ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Documents ] Predicate [ Document_Name = 'Robbin CV' ] Output [ Document_Name , Document_ID , Document_Description , Template_ID ]
# ```
# ================================================================================
# Question:
# Return the document id, template id, and description for the document with the name Robbin CV.
# ----------------------------------------
# Predicted:
# ScanTable [ Documents ] Predicate [ Document_Name = 'Robbin CV' ] Output [ Document_Description , Template_ID , Document_Name , Other_Details ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Documents ] Predicate [ Document_Name = 'Robbin CV' ] Output [ Document_Name , Document_ID , Document_Description , Template_ID ]
# ```
# ================================================================================
# Question:
# How many different templates do all document use?
# ----------------------------------------
# Predicted:
# Aggregate[ #1 ] Output [ countstar AS Count_Star ]
# ```
# ----------------------------------------
# True:
# Aggregate[ #1 ] Output [ COUNT(DISTINCT Template_ID) AS Count_Dist_Template_ID ]
# ```
# ================================================================================
# Question:
# Count the number of different templates used for documents.
# ----------------------------------------
# Predicted:
# Aggregate[ #1 ] Output [ countstar AS Count_Star ]
# ```
# ----------------------------------------
# True:
# Aggregate[ #1 ] Output [ COUNT(DISTINCT Template_ID) AS Count_Dist_Template_ID ]
# ```
# ================================================================================
# Question:
# What are the different template type codes?
# ----------------------------------------
# Predicted:
# ScanTable [ Ref_Template_Types ] Distinct [ true ] Output [ Template_Type_Code ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Templates ] Distinct [ true ] Output [ Template_Type_Code ]
# ```
# ================================================================================
# Question:
# What the smallest version number and its template type code?
# ----------------------------------------
# Predicted:
# Aggregate[ #1 ] Output [ MIN(Version_Number) AS Min_Version_Number , Template_Type_Code ]
# ```
# ----------------------------------------
# True:
# Aggregate[ #1 ] GroupBy [ Template_Type_Code ] Output [ Template_Type_Code , MIN(Version_Number) AS Min_Version_Number ]
# ```
# ================================================================================
# Question:
# Return the lowest version number, along with its corresponding template type code.
# ----------------------------------------
# Predicted:
# Aggregate[ #1 ] Output [ MIN(Version_Number) AS Min_Version_Number , Template_Type_Code ]
# ```
# ----------------------------------------
# True:
# Aggregate[ #1 ] GroupBy [ Template_Type_Code ] Output [ Template_Type_Code , MIN(Version_Number) AS Min_Version_Number ]
# ```
# ================================================================================
# Question:
# Return the type codes corresponding to templates with the description 'Presentation'.
# ----------------------------------------
# Predicted:
# ScanTable [ Templates ] Predicate [ Template_Details = 'Presentation' ] Output [ Template_Type_Code , Template_Details ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Ref_Template_Types ] Predicate [ Template_Type_Description = 'Presentation' ] Output [ Template_Type_Code , Template_Type_Description ]
# ```
# ================================================================================
# Question:
# Evaluating:  60%|█████▉    | 1803/3012 [00:00<00:00, 4340.21it/s]
# Show paragraph details for paragraph with text 'Korea ' .
# ----------------------------------------
# Predicted:
# ScanTable [ Paragraphs ] Predicate [ Paragraph_Text like '%Korea%' ] Output [ Paragraph_Text , Other_Details ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Paragraphs ] Predicate [ Paragraph_Text like 'korea' ] Output [ Paragraph_Text , Other_Details ]
# ```
# ================================================================================
# Question:
# What are the details for the paragraph that includes the text 'Korea ' ?
# ----------------------------------------
# Predicted:
# ScanTable [ Paragraphs ] Predicate [ Paragraph_Text like '%Korea%' ] Output [ Paragraph_Text , Other_Details ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Paragraphs ] Predicate [ Paragraph_Text like 'korea' ] Output [ Paragraph_Text , Other_Details ]
# ```
# ================================================================================
# Question:
# Show all document ids and the number of paragraphs in each document. Order by document id.
# ----------------------------------------
# Predicted:
# Sort[ #2 ] OrderBy [ Document_ID ASC ] Output [ Document_ID , Count_Star ]
# ```
# ----------------------------------------
# True:
# Sort[ #2 ] OrderBy [ Document_ID ] Output [ Document_ID , Count_Star ]
# ```
# ================================================================================
# Question:
# Return the document ids of all documents.
# ----------------------------------------
# Predicted:
# ScanTable [ Documents ] Output [ Document_ID ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Paragraphs ] Output [ Document_ID ]
# ```
# ================================================================================
# Question:
# Return the different document ids along with the number of paragraphs corresponding to each, ordered by id.
# ----------------------------------------
# Predicted:
# Sort[ #2 ] OrderBy [ Document_ID ASC ] Output [ Document_ID , Count_Star ]
# ```
# ----------------------------------------
# True:
# Sort[ #2 ] OrderBy [ Document_ID ] Output [ Document_ID , Count_Star ]
# ```
# ================================================================================
# Question:
# Show the document id with paragraph text 'Brazil'.
# ----------------------------------------
# Predicted:
# ScanTable [ Paragraphs ] Predicate [ Paragraph_Text = 'Brazil' ] Output [ Document_ID , Paragraph_Text ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Paragraphs ] Predicate [ Paragraph_Text = 'Brazil' ] Distinct [ true ] Output [ Document_ID , Paragraph_Text ]
# ```
# ================================================================================
# Question:
# What are the ids of documents that contain the paragraph text 'Brazil'?
# ----------------------------------------
# Predicted:
# ScanTable [ Paragraphs ] Predicate [ Paragraph_Text like '%Brazil%' ] Output [ Document_ID , Paragraph_Text ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Paragraphs ] Predicate [ Paragraph_Text = 'Brazil' ] Distinct [ true ] Output [ Document_ID , Paragraph_Text ]
# ```
# ================================================================================
# Question:
# What are the ids of documents that contain the paragraph text 'Ireland'?
# ----------------------------------------
# Predicted:
# ScanTable [ Paragraphs ] Predicate [ Paragraph_Text like '%Ireland%' ] Output [ Document_ID , Paragraph_Text ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Paragraphs ] Predicate [ Paragraph_Text = 'Ireland' ] Output [ Document_ID , Paragraph_Text ]
# ```
# ================================================================================
# Question:
# What is the age of the visitors whose membership level is not higher than 4?
# ----------------------------------------
# Predicted:
# ScanTable [ visitor ] Predicate [ Level_of_membership >= 4 ] Output [ Level_of_membership , Age ]
# ```
# ----------------------------------------
# True:
# ScanTable [ visitor ] Predicate [ Level_of_membership <= 4 ] Output [ Level_of_membership , Age ]
# ```
# ================================================================================
# Question:
# For each visitor, what is the id, name, membership level and the amount of money in total in all museum tickets spent by the visitor?
# ----------------------------------------
# Predicted:
# Join[ #2 , #3 ] Predicate [ #2.visitor_ID = #3.ID ] Output [ #3.Level_of_membership , #3.Name , #3.ID , #2.Sum_Total_spent ]
# ```
# ----------------------------------------
# True:
# Join[ #2 , #3 ] Predicate [ #2.visitor_ID = #3.ID ] Output [ #2.Sum_Total_spent , #3.Name , #2.visitor_ID , #3.Level_of_membership ]
# ```
# ================================================================================
# Question:
# What is the name of the visitor who visited a museum opened before 2009?
# ----------------------------------------
# Predicted:
# Join[ #3 , #4 ] Predicate [ #3.visitor_ID = #4.ID ] Output [ #4.Name ]
# ```
# ----------------------------------------
# True:
# Join[ #3 , #4 ] Predicate [ #3.visitor_ID = #4.ID ] Distinct [ true ] Output [ #4.Name ]
# ```
# ================================================================================
# Question:
# List 1 for each museum opened after 2013 or before 2008.
# ----------------------------------------
# Predicted:
# ScanTable [ museum ] Predicate [ Open_Year < 2008 OR Open_Year > 2013 ] Output [ Open_Year ]
# ```
# ----------------------------------------
# True:
# ScanTable [ museum ] Predicate [ Open_Year > 2013 OR Open_Year < 2008 ] Output [ Open_Year ]
# ```
# ================================================================================
# Question:
# List 1 for each player.
# ----------------------------------------
# Predicted:
# ScanTable [ player ] Output [ 1 AS One ]
# ```
# ----------------------------------------
# True:
# ScanTable [ players ] Output [ 1 AS One ]
# ```
# ================================================================================
# Question:
# List 1 for each player.
# ----------------------------------------
# Predicted:
# ScanTable [ player ] Output [ 1 AS One ]
# ```
# ----------------------------------------
# True:
# ScanTable [ players ] Output [ 1 AS One ]
# ```
# ================================================================================
# Question:
# Find the highest rank of losers in all matches.
# ----------------------------------------
# Predicted:
# Aggregate[ #1 ] Output [ MAX(loser_rank) AS Max_loser_rank ]
# ```
# ----------------------------------------
# True:
# Aggregate[ #1 ] Output [ MIN(loser_rank) AS Min_loser_rank ]
# ```
# ================================================================================
# Question:
# What is the best rank of losers across all matches?
# ----------------------------------------
# Predicted:
# Aggregate[ #1 ] Output [ MAX(loser_rank) AS Max_loser_rank ]
# ```
# ----------------------------------------
# True:
# Aggregate[ #1 ] Output [ MIN(loser_rank) AS Min_loser_rank ]
# ```
# ================================================================================
# Question:
# Find the distinct country codes of all players.
# ----------------------------------------
# Predicted:
# ScanTable [ country ] Distinct [ true ] Output [ country_code ]
# ```
# ----------------------------------------
# True:
# ScanTable [ players ] Distinct [ true ] Output [ country_code ]
# ```
# ================================================================================
# Question:
# find the number of distinct country codes of all players.
# ----------------------------------------
# Predicted:
# Aggregate[ #1 ] Output [ countstar AS Count_Star ]
# ```
# ----------------------------------------
# True:
# Aggregate[ #1 ] Output [ COUNT(DISTINCT country_code) AS Count_Dist_country_code ]
# ```
# ================================================================================
# Question:
# Find the distinct country codes the players come from.
# ----------------------------------------
# Predicted:
# ScanTable [ country ] Distinct [ true ] Output [ country_code ]
# ```
# ----------------------------------------
# True:
# ScanTable [ players ] Distinct [ true ] Output [ country_code ]
# ```
# ================================================================================
# Question:
# How many distinct countries do players come from?
# ----------------------------------------
# Predicted:
# Aggregate[ #1 ] Output [ countstar AS Count_Star ]
# ```
# ----------------------------------------
# True:
# Aggregate[ #1 ] Output [ COUNT(DISTINCT country_code) AS Count_Dist_country_code ]
# ```
# ================================================================================
# Question:
# Find the number of distinct name of losers.
# ----------------------------------------
# Predicted:
# Aggregate[ #1 ] Output [ countstar AS Count_Star ]
# ```
# ----------------------------------------
# True:
# Aggregate[ #1 ] Output [ COUNT(DISTINCT loser_name) AS Count_Dist_loser_name ]
# ```
# ================================================================================
# Question:
# How many different loser names are there?
# ----------------------------------------
# Predicted:
# Aggregate[ #1 ] Output [ countstar AS Count_Star ]
# ```
# ----------------------------------------
# True:
# Aggregate[ #1 ] Output [ COUNT(DISTINCT loser_name) AS Count_Dist_loser_name ]
# ```
# ================================================================================
# Question:
# ...
# Question:
# Show the ids and names of all students.
# ----------------------------------------
# Predicted:
# ScanTable [ Highschooler ] Output [ name , ID ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Likes ] Output [ student_id ]
# ```
# ================================================================================
# Question:
# Show the ids of students of all likes records.
# ----------------------------------------
# Predicted:
# ScanTable [ Likes ] Output [ student_id ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Highschooler ] Output [ ID , name ]
# ```
# ================================================================================
# Question:
# Show the ids of students and names of students of all likes.
# ----------------------------------------
# Predicted:
# Join[ #1 , #2 ] Predicate [ #1.student_id = #2.ID ] Output [ #2.name , #2.ID ]
# ```
# ----------------------------------------
# True:
# Join[ #1 , #2 ] Predicate [ #1.student_id = #2.ID ] Output [ #1.student_id , #2.name ]
# ```
# ================================================================================
# Question:
# What are the ids and names of all students?
# ----------------------------------------
# Predicted:
# ScanTable [ Highschooler ] Output [ name , ID ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Likes ] Output [ student_id ]
# ```
# ================================================================================
# Question:
# What are the ids of students of all likes records?
# ----------------------------------------
# Predicted:
# ScanTable [ Likes ] Output [ student_id ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Highschooler ] Output [ ID , name ]
# ```
# ================================================================================
# Question:
# What are the ids of students and names of students of all likes?
# ----------------------------------------
# Predicted:
# Join[ #1 , #2 ] Predicate [ #1.student_id = #2.ID ] Output [ #2.name , #2.ID ]
# ```
# ----------------------------------------
# True:
# Join[ #1 , #2 ] Predicate [ #1.student_id = #2.ID ] Output [ #1.student_id , #2.name ]
# ```
# ================================================================================
# Question:
# Which states have professionals living there?
# ----------------------------------------
# Predicted:
# ScanTable [ Professionals ] Distinct [ true ] Output [ state ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Professionals ] Output [ state ]
# ```
# ================================================================================
# Question:
# Find the states where professionals live.
# ----------------------------------------
# Predicted:
# ScanTable [ Professionals ] Distinct [ true ] Output [ state ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Professionals ] Output [ state ]
# ```
# ================================================================================
# Question:
# Which professionals live in the state of Indiana? List his or her id, last name and cell phone.
# ----------------------------------------
# Predicted:
# ScanTable [ Professionals ] Predicate [ state = 'IN' ] Output [ last_name , state , cell_number , professional_id ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Professionals ] Predicate [ state = 'Indiana' ] Output [ cell_number , last_name , professional_id , state ]
# ```
# ================================================================================
# Question:
# Find the id, last name and cell phone of the professionals who live in the state of Indiana.
# ----------------------------------------
# Predicted:
# ScanTable [ Professionals ] Predicate [ state = 'IN' ] Output [ last_name , state , cell_number , professional_id ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Professionals ] Predicate [ state = 'Indiana' ] Output [ cell_number , last_name , professional_id , state ]
# ```
# ================================================================================
# Question:
# Which first names are used for professionals?
# ----------------------------------------
# Predicted:
# ScanTable [ Professionals ] Distinct [ true ] Output [ first_name ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Professionals ] Output [ first_name ]
# ```
# ================================================================================
# Question:
# Which first names are used for owners?
# ----------------------------------------
# Predicted:
# ScanTable [ Owners ] Distinct [ true ] Output [ first_name ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Owners ] Output [ first_name ]
# ```
# ================================================================================
# Question:
# Which names are used for dogs?
# ----------------------------------------
# Predicted:
# ScanTable [ Dogs ] Distinct [ true ] Output [ name ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Dogs ] Output [ name ]
# ```
# ================================================================================
# Question:
# Find the first names that are used for dogs.
# ----------------------------------------
# Predicted:
# ScanTable [ Dogs ] Distinct [ true ] Output [ name ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Dogs ] Output [ name ]
# ```
# ================================================================================
# Question:
# Find the first names that are used for professionals or owners but are not used as dog names.
# ----------------------------------------
# Predicted:
# Except[ #3 , #4 ] Predicate [ #4.name like '%first_name%' ] Output [ #3.first_name ]
# ```
# ----------------------------------------
# True:
# Except[ #3 , #4 ] Predicate [ #4.name = #3.first_name ] Output [ #3.first_name ]
# ```
# ================================================================================
# Question:
# Which professional did not operate any treatment on dogs? List the professional's id, role and email.
# ----------------------------------------
# Predicted:
# Except[ #1 , #4 ] Predicate [ #4.role_code = #1.role_code ] Output [ #1.email_address , #1.professional_id , #1.role_code ]
# ```
# ----------------------------------------
# True:
# Except[ #1 , #4 ] Predicate [ #1.professional_id = #4.professional_id ] Output [ #1.email_address , #1.professional_id , #1.role_code ]
# ```
# ================================================================================
# Question:
# Give me the id, role and email of the professionals who did not perform any treatment on dogs.
# ----------------------------------------
# Predicted:
# Except[ #1 , #4 ] Predicate [ #4.role_code = 'treatment' ] Output [ #1.email_address , #1.role_code , #1.professional_id ]
# ```
# ----------------------------------------
# True:
# Except[ #1 , #4 ] Predicate [ #1.professional_id = #4.professional_id ] Output [ #1.email_address , #1.professional_id , #1.role_code ]
# ```
# ================================================================================
# Question:
# List the id of all owners.
# ----------------------------------------
# Predicted:
# ScanTable [ Owners ] Output [ owner_id ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Dogs ] Output [ owner_id ]
# ```
# ================================================================================
# Question:
# Return the id of all owners.
# ----------------------------------------
# Predicted:
# ScanTable [ Owners ] Output [ owner_id ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Dogs ] Output [ owner_id ]
# ```
# ================================================================================
# Question:
# What are id of the professionals who have done treatment with cost below average?
# ----------------------------------------
# Predicted:
# Join[ #2 , #3 ] Predicate [ #3.cost_of_treatment < #2.Avg_cost_of_treatment ] Output [ #3.professional_id ]
# ```
# ----------------------------------------
# True:
# Join[ #2 , #3 ] Predicate [ #3.cost_of_treatment < #2.Avg_cost_of_treatment ] Output [ #3.cost_of_treatment ]
# ```
# ================================================================================
# Question:
# What are the first name and last name of the professionals who have done treatment with cost below average?
# ----------------------------------------
# Predicted:
# Join[ #4 , #5 ] Predicate [ #4.cost_of_treatment = #5.last_name ] Output [ #5.first_name , #5.last_name ]
# ```
# ----------------------------------------
# True:
# Join[ #4 , #5 ] Distinct [ true ] Output [ #5.last_name , #5.first_name ]
# ```
# ================================================================================
# Question:
# List the rarest breed code.
# ----------------------------------------
# Predicted:
# TopSort[ #2 ] Rows [ 1 ] OrderBy [ Count_Star DESC ] Output [ Count_Star , breed_code ]
# ```
# ----------------------------------------
# True:
# TopSort[ #2 ] Rows [ 1 ] OrderBy [ Count_Star ASC ] Output [ breed_code , Count_Star ]
# ```
# ================================================================================
# Question:
# List the id and first name of owners living in Virginia.
# ----------------------------------------
# Predicted:
# ScanTable [ Owners ] Predicate [ state = 'VA' ] Output [ state , owner_id , first_name ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Owners ] Predicate [ state = 'Virginia' ] Output [ state , first_name , owner_id ]
# ```
# ================================================================================
# Question:
# Find the ids and first names of owners living in Virginia.
# ----------------------------------------
# Predicted:
# ScanTable [ Owners ] Predicate [ state = 'VA' ] Output [ state , owner_id , first_name ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Owners ] Predicate [ state = 'Virginia' ] Output [ state , first_name , owner_id ]
# ```
# ================================================================================
# Question:
# What are the arriving date and the departing date of the dogs who have gone through a treatment?
# ----------------------------------------
# Predicted:
# Join[ #1 , #2 ] Predicate [ #1.dog_id = #2.dog_id ] Output [ #2.date_departed , #2.date_arrived ]
# ```
# ----------------------------------------
# True:
# Join[ #1 , #2 ] Predicate [ #1.dog_id = #2.dog_id ] Distinct [ true ] Output [ #2.date_departed , #2.date_arrived ]
# ```
# ================================================================================
# Question:
# Find the arriving date and the departing date of the dogs that received a treatment.
# ----------------------------------------
# Predicted:
# Join[ #1 , #2 ] Predicate [ #1.dog_id = #2.dog_id ] Output [ #2.date_departed , #2.date_arrived ]
# ```
# ----------------------------------------
# True:
# Join[ #1 , #2 ] Predicate [ #1.dog_id = #2.dog_id ] Distinct [ true ] Output [ #2.date_departed , #2.date_arrived ]
# ```
# ================================================================================
# Question:
# List the id of the owner owning the youngest dog.
# ----------------------------------------
# Predicted:
# TopSort[ #3 ] Rows [ 1 ] OrderBy [ age ASC ] Output [ owner_id , age ]
# ```
# ----------------------------------------
# True:
# TopSort[ #3 ] Rows [ 1 ] OrderBy [ age DESC ] WithTies [ True ] Output [ age, owner_id ]
# ```
# ================================================================================
# Question:
# Who owns the youngest dog? Give me his or her id.
# ----------------------------------------
# Predicted:
# TopSort[ #3 ] Rows [ 1 ] OrderBy [ age ASC ] Output [ owner_id , age ]
# ```
# ----------------------------------------
# True:
# TopSort[ #3 ] Rows [ 1 ] OrderBy [ age DESC ] WithTies [ true ] Output [ owner_id ]
# ```
# ================================================================================
# Evaluating: 100%|██████████| 3012/3012 [00:00<00:00, 4350.09it/s]
# Question:
# What are all the possible breed type and size type combinations?
# ----------------------------------------
# Predicted:
# ScanTable [ Sizes ] Output [ size_description , size_code ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Dogs ] Distinct [ true ] Output [ breed_code , size_code ]
# ```
# ================================================================================
# Question:
# List the first name of all the professionals along with the description of the treatment they have done.
# ----------------------------------------
# Predicted:
# Join[ #1 , #4 ] Predicate [ #1.treatment_type_code = #4.treatment_type_code ] Output [ #4.first_name , #1.treatment_type_description ]
# ```
# ----------------------------------------
# True:
# Join[ #1 , #4 ] Predicate [ #1.treatment_type_code = #4.treatment_type_code ] Distinct [ true ] Output [ #1.treatment_type_description , #4.first_name ]
# ```
# ================================================================================
# Question:
# What are each professional's first name and description of the treatment they have performed?
# ----------------------------------------
# Predicted:
# Join[ #1 , #4 ] Predicate [ #1.treatment_type_code = #4.treatment_type_code ] Output [ #4.first_name , #1.treatment_type_description ]
# ```
# ----------------------------------------
# True:
# Join[ #1 , #4 ] Predicate [ #1.treatment_type_code = #4.treatment_type_code ] Distinct [ true ] Output [ #1.treatment_type_description , #4.first_name ]
# ```
# ================================================================================
# Question:
# What are the names of the singers who are not French citizens?
# ----------------------------------------
# Predicted:
# ScanTable [ singer ] Predicate [ Citizenship <> 'France' ] Output [ Nationality , Name ]
# ```
# ----------------------------------------
# True:
# ScanTable [ singer ] Predicate [ Citizenship <> 'France' ] Output [ Name , Citizenship ]
# ```
# ================================================================================
# Question:
# Show ids of singers that have songs with sales more than 300000.
# ----------------------------------------
# Predicted:
# ScanTable [ song ] Predicate [ Sales > 3000000.0 ] Output [ Sales , Singer_ID ]
# ```
# ----------------------------------------
# True:
# ScanTable [ song ] Predicate [ Sales > 300000.0 ] Output [ Singer_ID , Sales ]
# ```
# ================================================================================
# Question:
# What are the ids of the singers that have sales more than 300000?
# ----------------------------------------
# Predicted:
# ScanTable [ song ] Predicate [ Sales > 3000000.0 ] Output [ Sales , Singer_ID ]
# ```
# ----------------------------------------
# True:
# ScanTable [ song ] Predicate [ Sales > 300000.0 ] Output [ Singer_ID , Sales ]
# ```
# ================================================================================
# Question:
# Show the citizenship of singers with birth year before 1945.
# ----------------------------------------
# Predicted:
# ScanTable [ singer ] Predicate [ Birth_Year < 1945 ] Output [ Birth_Year , Citizenship ]
# ```
# ----------------------------------------
# True:
# ScanTable [ singer ] Predicate [ Birth_Year < 1945.0 ] Distinct [ true ] Output [ Birth_Year , Citizenship ]
# ```
# ================================================================================
# Question:
# What are the citizenships of singers with a birth year before 1945?
# ----------------------------------------
# Predicted:
# ScanTable [ singer ] Predicate [ Birth_Year < 1945 ] Output [ Birth_Year , Citizenship ]
# ```
# ----------------------------------------
# True:
# ScanTable [ singer ] Predicate [ Birth_Year < 1945.0 ] Distinct [ true ] Output [ Birth_Year , Citizenship ]
# ```
# ================================================================================
# Question:
# What are the names of properties that are apartments with more than 1 room?
# ----------------------------------------
# Predicted:
# ScanTable [ Properties ] Predicate [ room_count > 1 AND apt_feature_1 = 'apartment' ] Output [ apt_feature_1 , property_name , room_count ]
# ```
# ----------------------------------------
# True:
# ScanTable [ Properties ] Predicate [ room_count > 1 AND property_type_code = 'Apartment' ] Output [ property_type_code , property_name , room_count ]
# ```
# ================================================================================
# Accuracy: 2696/3012 = 89.51%
